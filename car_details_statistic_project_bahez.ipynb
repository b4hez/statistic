# %% [markdown]
# <a href="https://colab.research.google.com/github/b4hez/statistic/blob/main/car_details_statistic_project_bahez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car Details Dataset Analysis
#
# This notebook analyzes a dataset of used cars with the following features:
#
# - Car name
# - Year of manufacture
# - Kilometers driven
# - Selling price
# - Fuel type
#
# We’ll clean the data, explore key trends, and visualize relationships to better understand factors affecting car prices.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mydata = pd.read_csv('/content/car detail.csv')

# %%
mydata.tail(5)
# Out:
#                                          name  year  selling_price  km_driven  \
# 588                 Hyundai Verna 1.6 VTVT SX  2015         760000      55340
# 589                    Maruti Swift Dzire VDI  2017         600000      46507
# 590            Renault Duster 85PS Diesel RxL  2013         450000       1000
# 591  Mercedes-Benz C-Class Progressive C 220d  2018        3800000      10000
# 592                   Audi A4 3.0 TDI Quattro  2013        1580000      86000
#
#        fuel       seller_type
# 588  Petrol  Trustmark Dealer
# 589  Diesel  Trustmark Dealer
# 590  Diesel            Dealer
# 591  Diesel            Dealer
# 592  Diesel            Dealer

# %%
# Load the dataset
mydata = pd.read_csv('/content/car detail.csv')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593 entries, 0 to 592
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           593 non-null    object
#  1   year           593 non-null    int64
#  2   selling_price  593 non-null    int64
#  3   km_driven      593 non-null    int64
#  4   fuel           593 non-null    object
#  5   seller_type    593 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 27.9+ KB

# %%
mydata.describe()
# Out:
#               year  selling_price      km_driven
# count   593.000000   5.930000e+02     593.000000
# mean   2013.160202   5.642276e+05   67325.234401
# std       4.102937   6.895046e+05   49049.382725
# min    1996.000000   4.000000e+04    1000.000000
# 25%    2011.000000   2.250000e+05   33000.000000
# 50%    2014.000000   3.900000e+05   60000.000000
# 75%    2017.000000   6.400000e+05   90000.000000
# max    2020.000000   8.150000e+06  560000.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="year", y="selling_price", data=mydata)
# Out:
# <Axes: xlabel='year', ylabel='selling_price'>

# %%
pd.crosstab(mydata['year'],mydata['km_driven'] )
# Out:
# km_driven  1000    1136    1250    2650    3240    3600    4000    4500    \
# year
# 1996            0       0       0       0       0       0       0       0
# 1998            0       0       0       0       0       0       0       0
# 1999            0       0       0       0       0       0       0       0
# 2000            0       0       0       0       0       0       0       0
# 2001            0       0       0       0       0       0       0       0
# 2002            0       0       0       0       0       0       0       0
# 2003            0       0       0       0       0       0       0       0
# 2004            0       0       0       0       0       0       0       0
# 2005            0       0       0       0       0       0       0       0
# 2006            0       0       0       0       0       0       0       0
# 2007            0       0       0       0       0       0       0       0
# 2008            0       0       0       0       0       0       0       0
# ...

# %%
pd.crosstab(mydata['name'],mydata['km_driven'] )
# Out:
# km_driven                                     1000    1136    1250    2650    \
# name
# Audi A4 2.0 TDI 177 Bhp Premium Plus               0       0       0       0
# Audi A4 3.0 TDI Quattro                            0       0       0       0
# Audi A6 2.0 TDI  Design Edition                    0       0       0       0
# Audi A6 2.0 TDI Premium Plus                       0       0       0       0
# Audi A8 4.2 TDI                                    0       0       0       0
# ...                                              ...     ...     ...     ...
# Volkswagen Polo GTI                                0       0       0       0
# Volkswagen Polo Petrol Comfortline 1.2L            0       0       0       0
# Volkswagen Vento Celeste 1.5 TDI Highline AT       0       0       0       0
# Volkswagen Vento Diesel Highline                   0       0       0       0
# Volvo V40 D3 R Design                              0       0       0       0
#
# ...

# %%
sns.countplot(x="km_driven", hue="year", data=mydata)
# Out:
# <Axes: xlabel='km_driven', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['name', 'seller_type'],
                     columns=[ 'fuel'], aggfunc=len)
# Out:
#                                                          km_driven             \
# fuel                                                           CNG Diesel LPG
# name                                         seller_type
# Audi A4 2.0 TDI 177 Bhp Premium Plus         Dealer            NaN    1.0 NaN
# Audi A4 3.0 TDI Quattro                      Dealer            NaN    3.0 NaN
# Audi A6 2.0 TDI  Design Edition              Dealer            NaN    1.0 NaN
# Audi A6 2.0 TDI Premium Plus                 Dealer            NaN    3.0 NaN
# Audi A8 4.2 TDI                              Dealer            NaN    1.0 NaN
# ...                                                            ...    ...  ..
# Volkswagen Polo GTI                          Dealer            NaN    NaN NaN
# Volkswagen Polo Petrol Comfortline 1.2L      Individual        NaN    NaN NaN
# Volkswagen Vento Celeste 1.5 TDI Highline AT Individual        NaN    1.0 NaN
# ...

# %%
pd.pivot_table(mydata, values='year', index=['name'],
                     columns=[ 'fuel'], aggfunc='mean') # or any other applicable numeric column like 'km_driven'
# Out:
# fuel                                          CNG       Diesel  LPG  Petrol
# name
# Audi A4 2.0 TDI 177 Bhp Premium Plus          NaN  2013.000000  NaN     NaN
# Audi A4 3.0 TDI Quattro                       NaN  2013.000000  NaN     NaN
# Audi A6 2.0 TDI  Design Edition               NaN  2013.000000  NaN     NaN
# Audi A6 2.0 TDI Premium Plus                  NaN  2013.333333  NaN     NaN
# Audi A8 4.2 TDI                               NaN  2013.000000  NaN     NaN
# ...                                           ...          ...  ...     ...
# Volkswagen Polo GTI                           NaN          NaN  NaN  2017.0
# Volkswagen Polo Petrol Comfortline 1.2L       NaN          NaN  NaN  2013.0
# Volkswagen Vento Celeste 1.5 TDI Highline AT  NaN  2016.000000  NaN     NaN
# Volkswagen Vento Diesel Highline              NaN  2011.000000  NaN     NaN
# Volvo V40 D3 R Design                         NaN  2018.000000  NaN     NaN
#
# [408 rows x 4 columns]

# %%
mydata['year'].std()
# Out:
# 4.102936649300115

# %%
mydata['year'].mean()
# Out:
# np.float64(2013.1602023608768)

# %%
sns.displot(mydata['year'])

# %%
mydata.hist(by='fuel',column = 'seller_type')
# Out:
# array([[<Axes: title={'center': 'CNG'}>,
#         <Axes: title={'center': 'Diesel'}>],
#        [<Axes: title={'center': 'LPG'}>,
#         <Axes: title={'center': 'Petrol'}>]], dtype=object)

# %%
mydata.hist(by='seller_type',column = 'fuel')
# Out:
# array([[<Axes: title={'center': 'Dealer'}>,
#         <Axes: title={'center': 'Individual'}>],
#        [<Axes: title={'center': 'Trustmark Dealer'}>, <Axes: >]],
#       dtype=object)

# %%
mydata.hist(by='seller_type',column = 'fuel')
# Out:
# array([[<Axes: title={'center': 'Dealer'}>,
#         <Axes: title={'center': 'Individual'}>],
#        [<Axes: title={'center': 'Trustmark Dealer'}>, <Axes: >]],
#       dtype=object)

# %%
mydata.hist(by='year',column = 'km_driven', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': '1996'}>,
#         <Axes: title={'center': '1998'}>,
#         <Axes: title={'center': '1999'}>,
#         <Axes: title={'center': '2000'}>,
#         <Axes: title={'center': '2001'}>],
#        [<Axes: title={'center': '2002'}>,
#         <Axes: title={'center': '2003'}>,
#         <Axes: title={'center': '2004'}>,
#         <Axes: title={'center': '2005'}>,
#         <Axes: title={'center': '2006'}>],
#        [<Axes: title={'center': '2007'}>,
#         <Axes: title={'center': '2008'}>,
#         <Axes: title={'center': '2009'}>,
#         <Axes: title={'center': '2010'}>,
#         <Axes: title={'center': '2011'}>],
#        [<Axes: title={'center': '2012'}>,
#         <Axes: title={'center': '2013'}>,
#         <Axes: title={'center': '2014'}>,
#         <Axes: title={'center': '2015'}>,
#         <Axes: title={'center': '2016'}>],
#        [<Axes: title={'center': '2017'}>,
#         <Axes: title={'center': '2018'}>,
# ...

# %%
sns.pairplot(mydata)

# %% [markdown]
# <style>
#   ul {
#     background-color: black;
#   }
#
# <div>
# <span style="color: pink;">
# <h2> Project: concider specification of your dataset </h2>
#     <h3>
#     <ul>
#   <li>Apply all above codes</li>
#   <li>Allways be creative to find interested information</li>
#   <li> Arrange and clean up your GitHub</li>
#     </ul>
#     </h3>
# </div>
#     </style>

# %% [markdown]
# <ul style="background-color: gray;">
#     <div style="color: yalow;font-size: 46px>
#   <li>analyze</li>
#   <li>create</li>
#                 </div>
# </ul>
